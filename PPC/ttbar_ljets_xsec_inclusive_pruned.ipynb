# %%
import pytensor 
import pymc as pm
import arviz as az
import pyhf
import numpy as np
import matplotlib.pyplot as plt
import json
import time

from pytensor import tensor as pt
from pytensor.graph.basic import Apply

# %% [markdown]
# # Prior-Predictive Checks for ttbar
#
# We perform some prior-predictive checks for [this measurement](https://www.hepdata.net/record/ins1869695).

# %% [markdown]
# ### Set-Up
#  ... pyhf model set-up.

# %%
### Open the .json file
with open("ttbar_ljets_xsec_inclusive_pruned.json") as serialized:
    spec = json.load(serialized)

### Create pyhf model from it
workspace = pyhf.Workspace(spec)

model = workspace.model()

### Some model specs
nPars = len(model.config.suggested_init())
obs = workspace.data(model, include_auxdata=False)

# %% [markdown]
# ... print the specifications.

# %%
print(f"channels: {model.config.channels}")
print(".........")
print(f"nbins: {model.config.channel_nbins}")
print(".........")
print(f"samples: {model.config.samples}")
print(".........")
print(f"modifiers: {model.config.modifiers}")
print(".........")
print(f"parameters: {model.config.parameters}")
print(".........")
print(f"nauxdata: {model.config.nauxdata}")
print(".........")
print(f"auxdata: {model.config.auxdata}")

# %% [markdown]
# ### Class
#
# ... Op creation.

# %%
### Class that creates the model Op
class Op(pt.Op):
    itypes = [pt.dvector]  # Expects a vector of parameter values
    otypes = [pt.dvector]  # Outputs a vector of values (the model.expected_actualdata)

    def __init__(self, name, func):
        ## Add inputs as class attributes
        self.func = func
        self.name = name

    def perform(self, node, inputs, outputs):
        ## Method that is used when calling the Op
        (theta,) = inputs  # Contains my variables

        ## Calling input function (in our case the model.expected_actualdata)
        result = self.func(theta)

        ## Output values of model.expected_actualdata
        outputs[0][0] = np.asarray(result, dtype=node.outputs[0].dtype)

# %% [markdown]
# ## No Observations

# %%
### Applying the Op with arguments (function, name)
mainOp = Op("mainOp", model.expected_actualdata)

start_time = time.time()
### Opening the pyMC model space
with pm.Model() as basic_model:
    ## TensorVar input parameters [sigStr, gamma_i, ... ,gamma_nBins]
    pars = [pm.HalfNormal("sigStr", sigma=2)]
    pars.extend(pm.Gamma(f"gamma{idx}", alpha=20, beta=20) for idx in range(132))
    pars = pt.as_tensor_variable(pars)

    # main = pm.Poisson("main", mu=mainDet, observed=obs)
    # mainPoiss = pm.Poisson("mainPoiss", mu=mainOp(pars), observed=obs)
    mainPoiss = pm.Poisson("mainPoiss", mu=mainOp(pars))

    ## Sampling ...
    post_data = pm.sample(5)
    # prior_data = pm.sample_prior_predictive()
    # post_pred = pm.sample_posterior_predictive(post_data)

print("...............................................")
print(f"That took {(time.time() - start_time)/60} minutes ...")
# Out:
# Only 5 samples in chain.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >CompoundStep
# >>Slice: [sigStr]
# >>Slice: [gamma0]
# >>Slice: [gamma1]
# >>Slice: [gamma2]
# >>Slice: [gamma3]
# >>Slice: [gamma4]
# >>Slice: [gamma5]
# >>Slice: [gamma6]
# >>Slice: [gamma7]
# >>Slice: [gamma8]
# >>Slice: [gamma9]
# >>Slice: [gamma10]
# >>Slice: [gamma11]
# >>Slice: [gamma12]
# >>Slice: [gamma13]
# >>Slice: [gamma14]
# >>Slice: [gamma15]
# >>Slice: [gamma16]
# >>Slice: [gamma17]
# >>Slice: [gamma18]
# >>Slice: [gamma19]
# >>Slice: [gamma20]
# >>Slice: [gamma21]
# >>Slice: [gamma22]
# >>Slice: [gamma23]
# >>Slice: [gamma24]
# >>Slice: [gamma25]
# >>Slice: [gamma26]
# >>Slice: [gamma27]
# >>Slice: [gamma28]
# >>Slice: [gamma29]
# >>Slice: [gamma30]
# >>Slice: [gamma31]
# >>Slice: [gamma32]
# >>Slice: [gamma33]
# >>Slice: [gamma34]
# >>Slice: [gamma35]
# >>Slice: [gamma36]
# >>Slice: [gamma37]
# >>Slice: [gamma38]
# >>Slice: [gamma39]
# >>Slice: [gamma40]
# >>Slice: [gamma41]
# >>Slice: [gamma42]
# >>Slice: [gamma43]
# >>Slice: [gamma44]
# >>Slice: [gamma45]
# >>Slice: [gamma46]
# >>Slice: [gamma47]
# >>Slice: [gamma48]
# >>Slice: [gamma49]
# >>Slice: [gamma50]
# >>Slice: [gamma51]
# >>Slice: [gamma52]
# >>Slice: [gamma53]
# >>Slice: [gamma54]
# >>Slice: [gamma55]
# >>Slice: [gamma56]
# >>Slice: [gamma57]
# >>Slice: [gamma58]
# >>Slice: [gamma59]
# >>Slice: [gamma60]
# >>Slice: [gamma61]
# >>Slice: [gamma62]
# >>Slice: [gamma63]
# >>Slice: [gamma64]
# >>Slice: [gamma65]
# >>Slice: [gamma66]
# >>Slice: [gamma67]
# >>Slice: [gamma68]
# >>Slice: [gamma69]
# >>Slice: [gamma70]
# >>Slice: [gamma71]
# >>Slice: [gamma72]
# >>Slice: [gamma73]
# >>Slice: [gamma74]
# >>Slice: [gamma75]
# >>Slice: [gamma76]
# >>Slice: [gamma77]
# >>Slice: [gamma78]
# >>Slice: [gamma79]
# >>Slice: [gamma80]
# >>Slice: [gamma81]
# >>Slice: [gamma82]
# >>Slice: [gamma83]
# >>Slice: [gamma84]
# >>Slice: [gamma85]
# >>Slice: [gamma86]
# >>Slice: [gamma87]
# >>Slice: [gamma88]
# >>Slice: [gamma89]
# >>Slice: [gamma90]
# >>Slice: [gamma91]
# >>Slice: [gamma92]
# >>Slice: [gamma93]
# >>Slice: [gamma94]
# >>Slice: [gamma95]
# >>Slice: [gamma96]
# >>Slice: [gamma97]
# >>Slice: [gamma98]
# >>Slice: [gamma99]
# >>Slice: [gamma100]
# >>Slice: [gamma101]
# >>Slice: [gamma102]
# >>Slice: [gamma103]
# >>Slice: [gamma104]
# >>Slice: [gamma105]
# >>Slice: [gamma106]
# >>Slice: [gamma107]
# >>Slice: [gamma108]
# >>Slice: [gamma109]
# >>Slice: [gamma110]
# >>Slice: [gamma111]
# >>Slice: [gamma112]
# >>Slice: [gamma113]
# >>Slice: [gamma114]
# >>Slice: [gamma115]
# >>Slice: [gamma116]
# >>Slice: [gamma117]
# >>Slice: [gamma118]
# >>Slice: [gamma119]
# >>Slice: [gamma120]
# >>Slice: [gamma121]
# >>Slice: [gamma122]
# >>Slice: [gamma123]
# >>Slice: [gamma124]
# >>Slice: [gamma125]
# >>Slice: [gamma126]
# >>Slice: [gamma127]
# >>Slice: [gamma128]
# >>Slice: [gamma129]
# >>Slice: [gamma130]
# >>Slice: [gamma131]
# >Metropolis: [mainPoiss]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='4020' class='' max='4020' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [4020/4020 09:45&lt;00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 5 draw iterations (4_000 + 20 draws total) took 586 seconds.
# ...............................................
# That took 57.5561505039533 minutes ...
# /var/folders/p9/sw_pjm3j027cxfs57s_91bfw0000gn/T/ipykernel_15489/3483040292.py:16: UserWarning: The number of samples is too small to check convergence reliably.
#   post_data = pm.sample(5)

# %%
az.summary(post_data)
# Out:
#                      mean         sd       hdi_3%      hdi_97%  mcse_mean  \
# mainPoiss[0]  1369564.250  11631.102  1356895.000  1382944.000   2649.879
# mainPoiss[1]   817275.300   1993.711   815011.000   820110.000    454.221
# mainPoiss[2]   699002.150   4748.864   690675.000   702677.000   1081.919
# mainPoiss[3]   586394.400   4490.517   580533.000   592241.000   1023.061
# mainPoiss[4]   498942.050   6019.421   492900.000   507294.000   1371.386
# ...                   ...        ...          ...          ...        ...
# gamma127            0.967      0.063        0.902        1.054      0.014
# gamma128            0.959      0.039        0.915        1.019      0.009
# gamma129            1.045      0.056        0.965        1.123      0.013
# gamma130            1.015      0.037        0.971        1.077      0.009
# gamma131            1.042      0.193        0.735        1.354      0.044
#
#                mcse_sd  ess_bulk  ess_tail  r_hat
# mainPoiss[0]  1902.869      19.0      16.0   3.17
# mainPoiss[1]   326.175      19.0      19.0   4.67
# mainPoiss[2]   776.923      19.0      16.0   5.29
# mainPoiss[3]   734.657      19.0      19.0   3.65
# mainPoiss[4]   984.788      19.0      19.0   4.58
# ...                ...       ...       ...    ...
# gamma127         0.010      19.0      19.0   4.30
# gamma128         0.006      19.0      19.0   3.23
# gamma129         0.009      19.0      19.0   3.07
# gamma130         0.006      19.0      19.0   2.88
# gamma131         0.032      19.0      16.0   1.09
#
# [170 rows x 9 columns]

# %% [markdown]
# ## Include some observations

# %%
### Applying the Op with arguments (function, name)
mainOp = Op("mainOp", model.expected_actualdata)

### Opening the pyMC model space
start_time = time.time()
with pm.Model() as basic_model:
    ## TensorVar input parameters [sigStr, gamma_i, ... ,gamma_nBins]
    pars = [pm.HalfNormal("sigStr", sigma=2)]
    pars.extend(pm.Gamma(f"gamma{idx}", alpha=20, beta=20) for idx in range(132))
    pars = pt.as_tensor_variable(pars)

    mainPoiss = pm.Poisson("mainPoiss", mu=mainOp(pars), observed=obs)

    ## Sampling ...
    post_data = pm.sample(5)
    # prior_data = pm.sample_prior_predictive()
    # post_pred = pm.sample_posterior_predictive(post_data)

print("...............................................")
print(f"That took {(time.time() - start_time)/60} minutes ...")
# Out:
# Only 5 samples in chain.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >Slice: [sigStr]
# >Slice: [gamma0]
# >Slice: [gamma1]
# >Slice: [gamma2]
# >Slice: [gamma3]
# >Slice: [gamma4]
# >Slice: [gamma5]
# >Slice: [gamma6]
# >Slice: [gamma7]
# >Slice: [gamma8]
# >Slice: [gamma9]
# >Slice: [gamma10]
# >Slice: [gamma11]
# >Slice: [gamma12]
# >Slice: [gamma13]
# >Slice: [gamma14]
# >Slice: [gamma15]
# >Slice: [gamma16]
# >Slice: [gamma17]
# >Slice: [gamma18]
# >Slice: [gamma19]
# >Slice: [gamma20]
# >Slice: [gamma21]
# >Slice: [gamma22]
# >Slice: [gamma23]
# >Slice: [gamma24]
# >Slice: [gamma25]
# >Slice: [gamma26]
# >Slice: [gamma27]
# >Slice: [gamma28]
# >Slice: [gamma29]
# >Slice: [gamma30]
# >Slice: [gamma31]
# >Slice: [gamma32]
# >Slice: [gamma33]
# >Slice: [gamma34]
# >Slice: [gamma35]
# >Slice: [gamma36]
# >Slice: [gamma37]
# >Slice: [gamma38]
# >Slice: [gamma39]
# >Slice: [gamma40]
# >Slice: [gamma41]
# >Slice: [gamma42]
# >Slice: [gamma43]
# >Slice: [gamma44]
# >Slice: [gamma45]
# >Slice: [gamma46]
# >Slice: [gamma47]
# >Slice: [gamma48]
# >Slice: [gamma49]
# >Slice: [gamma50]
# >Slice: [gamma51]
# >Slice: [gamma52]
# >Slice: [gamma53]
# >Slice: [gamma54]
# >Slice: [gamma55]
# >Slice: [gamma56]
# >Slice: [gamma57]
# >Slice: [gamma58]
# >Slice: [gamma59]
# >Slice: [gamma60]
# >Slice: [gamma61]
# >Slice: [gamma62]
# >Slice: [gamma63]
# >Slice: [gamma64]
# >Slice: [gamma65]
# >Slice: [gamma66]
# >Slice: [gamma67]
# >Slice: [gamma68]
# >Slice: [gamma69]
# >Slice: [gamma70]
# >Slice: [gamma71]
# >Slice: [gamma72]
# >Slice: [gamma73]
# >Slice: [gamma74]
# >Slice: [gamma75]
# >Slice: [gamma76]
# >Slice: [gamma77]
# >Slice: [gamma78]
# >Slice: [gamma79]
# >Slice: [gamma80]
# >Slice: [gamma81]
# >Slice: [gamma82]
# >Slice: [gamma83]
# >Slice: [gamma84]
# >Slice: [gamma85]
# >Slice: [gamma86]
# >Slice: [gamma87]
# >Slice: [gamma88]
# >Slice: [gamma89]
# >Slice: [gamma90]
# >Slice: [gamma91]
# >Slice: [gamma92]
# >Slice: [gamma93]
# >Slice: [gamma94]
# >Slice: [gamma95]
# >Slice: [gamma96]
# >Slice: [gamma97]
# >Slice: [gamma98]
# >Slice: [gamma99]
# >Slice: [gamma100]
# >Slice: [gamma101]
# >Slice: [gamma102]
# >Slice: [gamma103]
# >Slice: [gamma104]
# >Slice: [gamma105]
# >Slice: [gamma106]
# >Slice: [gamma107]
# >Slice: [gamma108]
# >Slice: [gamma109]
# >Slice: [gamma110]
# >Slice: [gamma111]
# >Slice: [gamma112]
# >Slice: [gamma113]
# >Slice: [gamma114]
# >Slice: [gamma115]
# >Slice: [gamma116]
# >Slice: [gamma117]
# >Slice: [gamma118]
# >Slice: [gamma119]
# >Slice: [gamma120]
# >Slice: [gamma121]
# >Slice: [gamma122]
# >Slice: [gamma123]
# >Slice: [gamma124]
# >Slice: [gamma125]
# >Slice: [gamma126]
# >Slice: [gamma127]
# >Slice: [gamma128]
# >Slice: [gamma129]
# >Slice: [gamma130]
# >Slice: [gamma131]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='2300' class='' max='4020' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       57.21% [2300/4020 07:28&lt;05:35 Sampling 4 chains, 0 divergences]
#     </div>
# /Users/malinhorstmann/anaconda3/envs/pymc_env/lib/python3.11/site-packages/pyhf/interpolators/code4p.py:94: RuntimeWarning: invalid value encountered in add
#   deltas = tmp3_times_A + alphas_times_S
# /Users/malinhorstmann/anaconda3/envs/pymc_env/lib/python3.11/site-packages/numpy/core/fromnumeric.py:86: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# /Users/malinhorstmann/anaconda3/envs/pymc_env/lib/python3.11/site-packages/pyhf/tensor/numpy_backend.py:281: RuntimeWarning: overflow encountered in power
#   return np.power(tensor_in_1, tensor_in_2)
# /Users/malinhorstmann/anaconda3/envs/pymc_env/lib/python3.11/site-packages/pyhf/interpolators/code4p.py:87: RuntimeWarning: overflow encountered in multiply
#   tmp2 = asquare * tmp1 + 15.0
# /Users/malinhorstmann/anaconda3/envs/pymc_env/lib/python3.11/site-packages/pyhf/interpolators/code4p.py:88: RuntimeWarning: overflow encountered in multiply
#   tmp3 = asquare * tmp2
# /Users/malinhorstmann/anaconda3/envs/pymc_env/lib/python3.11/site-packages/pyhf/interpolators/code4p.py:94: RuntimeWarning: invalid value encountered in add
#   deltas = tmp3_times_A + alphas_times_S
# /Users/malinhorstmann/anaconda3/envs/pymc_env/lib/python3.11/site-packages/numpy/core/fromnumeric.py:86: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# /Users/malinhorstmann/anaconda3/envs/pymc_env/lib/python3.11/site-packages/pyhf/tensor/numpy_backend.py:281: RuntimeWarning: overflow encountered in power
#   return np.power(tensor_in_1, tensor_in_2)
# /Users/malinhorstmann/anaconda3/envs/pymc_env/lib/python3.11/site-packages/pyhf/interpolators/code4p.py:87: RuntimeWarning: overflow encountered in multiply
#   tmp2 = asquare * tmp1 + 15.0
# /Users/malinhorstmann/anaconda3/envs/pymc_env/lib/python3.11/site-packages/pyhf/interpolators/code4p.py:88: RuntimeWarning: overflow encountered in multiply
#   tmp3 = asquare * tmp2
# /Users/malinhorstmann/anaconda3/envs/pymc_env/lib/python3.11/site-packages/pyhf/interpolators/code4p.py:94: RuntimeWarning: invalid value encountered in add
#   deltas = tmp3_times_A + alphas_times_S
# /Users/malinhorstmann/anaconda3/envs/pymc_env/lib/python3.11/site-packages/numpy/core/fromnumeric.py:86: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# /Users/malinhorstmann/anaconda3/envs/pymc_env/lib/python3.11/site-packages/pyhf/tensor/numpy_backend.py:281: RuntimeWarning: overflow encountered in power
#   return np.power(tensor_in_1, tensor_in_2)
# /Users/malinhorstmann/anaconda3/envs/pymc_env/lib/python3.11/site-packages/pyhf/interpolators/code4p.py:94: RuntimeWarning: invalid value encountered in add
#   deltas = tmp3_times_A + alphas_times_S
# /Users/malinhorstmann/anaconda3/envs/pymc_env/lib/python3.11/site-packages/numpy/core/fromnumeric.py:86: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# /Users/malinhorstmann/anaconda3/envs/pymc_env/lib/python3.11/site-packages/pyhf/interpolators/code4p.py:88: RuntimeWarning: overflow encountered in multiply
#   tmp3 = asquare * tmp2
# /Users/malinhorstmann/anaconda3/envs/pymc_env/lib/python3.11/site-packages/pyhf/tensor/numpy_backend.py:281: RuntimeWarning: overflow encountered in power
#   return np.power(tensor_in_1, tensor_in_2)
# /Users/malinhorstmann/anaconda3/envs/pymc_env/lib/python3.11/site-packages/pyhf/interpolators/code4p.py:87: RuntimeWarning: overflow encountered in multiply
#   tmp2 = asquare * tmp1 + 15.0
# /Users/malinhorstmann/anaconda3/envs/pymc_env/lib/python3.11/site-packages/pyhf/interpolators/code4p.py:87: RuntimeWarning: overflow encountered in multiply
#   tmp2 = asquare * tmp1 + 15.0
# /Users/malinhorstmann/anaconda3/envs/pymc_env/lib/python3.11/site-packages/pyhf/interpolators/code4p.py:88: RuntimeWarning: overflow encountered in multiply
#   tmp3 = asquare * tmp2
# /Users/malinhorstmann/anaconda3/envs/pymc_env/lib/python3.11/site-packages/numpy/core/fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# /Users/malinhorstmann/anaconda3/envs/pymc_env/lib/python3.11/site-packages/numpy/core/fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# /Users/malinhorstmann/anaconda3/envs/pymc_env/lib/python3.11/site-packages/numpy/core/fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# /Users/malinhorstmann/anaconda3/envs/pymc_env/lib/python3.11/site-packages/numpy/core/fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[99], line 17
#      14     mainPoiss = pm.Poisson("mainPoiss", mu=mainOp(pars), observed=obs)
#      16     ## Sampling ...
# ---> 17     post_data = pm.sample(5)
#      18     # prior_data = pm.sample_prior_predictive()
#      19     # post_pred = pm.sample_posterior_predictive(post_data)
#      21 print("...............................................")
#
# File ~/anaconda3/envs/pymc_env/lib/python3.11/site-packages/pymc/sampling/mcmc.py:571, in sample(draws, step, init, n_init, initvals, trace, chains, cores, tune, progressbar, model, random_seed, discard_tuned_samples, compute_convergence_checks, callback, jitter_max_retries, return_inferencedata, keep_warning_stat, idata_kwargs, mp_ctx, **kwargs)
#     569 # Wrap chain traces in a MultiTrace
#     570 if discard_tuned_samples:
# --> 571     traces, length = _choose_chains(traces, tune)
#     572 else:
#     573     traces, length = _choose_chains(traces, 0)
#
# File ~/anaconda3/envs/pymc_env/lib/python3.11/site-packages/pymc/backends/base.py:527, in _choose_chains(traces, tune)
#     525 lengths = [max(0, len(trace) - tune) for trace in traces]
#     526 if not sum(lengths):
# --> 527     raise ValueError("Not enough samples to build a trace.")
#     529 idxs = np.argsort(lengths)
#     530 l_sort = np.array(lengths)[idxs]
#
# ValueError: Not enough samples to build a trace.
